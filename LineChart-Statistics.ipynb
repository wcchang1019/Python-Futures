# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('LineChart_onehour.csv')
df = df.drop(df.index[0])
df = df.reset_index()
del df['index']
dfgroup = df.groupby(by='Category')
dfgroupedlist = list(dfgroup)
CategorySize = list(dfgroup.size())
labels = ['b-horn','b-wait','s-wait','s-convergence','s-horn','b-strong','s-strong','buy-convergence','b-end','s-end']
colors = ['blue','red','green','yellow','blue','red','green','yellow','red','green']

# %%
plt.pie(CategorySize , labels=labels , colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
# Out:
# (-1.1150408796084414,
#  1.1018291206616724,
#  -1.1115542968182295,
#  1.1037365815509317)

# %%
fig , (ax0,ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9) = plt.subplots(figsize=(16,20),nrows=10)
plt.subplots_adjust(hspace = 0.4)
ax0.hist(dfgroupedlist[0][1]['All_Time'],bins=20,edgecolor='black')
ax0.set_title('b-horn')
ax1.hist(dfgroupedlist[1][1]['All_Time'],bins=20,edgecolor='black')
ax1.set_title('b-wait')
ax2.hist(dfgroupedlist[2][1]['All_Time'],bins=20,edgecolor='black')
ax2.set_title('s-wait')
ax3.hist(dfgroupedlist[3][1]['All_Time'],bins=20,edgecolor='black')
ax3.set_title('s-convergence')
ax4.hist(dfgroupedlist[4][1]['All_Time'],bins=20,edgecolor='black')
ax4.set_title('s-horn')
ax5.hist(dfgroupedlist[5][1]['All_Time'],bins=20,edgecolor='black')
ax5.set_title('b-strong')
ax6.hist(dfgroupedlist[6][1]['All_Time'],bins=20,edgecolor='black')
ax6.set_title('s-strong')
ax7.hist(dfgroupedlist[7][1]['All_Time'],bins=20,edgecolor='black')
ax7.set_title('b-convergence')
ax8.hist(dfgroupedlist[8][1]['All_Time'],bins=20,edgecolor='black')
ax8.set_title('b-end')
ax9.hist(dfgroupedlist[9][1]['All_Time'],bins=20,edgecolor='black')
ax9.set_title('s-end')
# Out:
# Text(0.5,1,'s-end')

# %%
pre = list(df['Category'])
pre.insert(0,0)
pre.pop()
df['pre'] = pre
df_group_pre = df.groupby(['pre','Category'])
dict_category = {1:'b-horn',2:'b-wait',3:'s-wait',4:'s-convergence',5:'s-horn',6:'b-strong',7:'s-strong',8:'buy-convergence',9:'b-end',10:'s-end'}

# %%
def plot_know_pre_pie(num):
    piesize = list(df_group_pre.size()[num])
    labels = list(map(lambda x :dict_category[x],list(df_group_pre.size()[num].index)))
    plt.figure(figsize=(6,6))
    plt.pie(piesize,labels=labels,autopct='%1.1f%%')
    plt.title('pre is '+dict_category[num])

# %%
plot_know_pre_pie(1)
plot_know_pre_pie(2)
plot_know_pre_pie(3)
plot_know_pre_pie(4)
plot_know_pre_pie(5)
plot_know_pre_pie(6)
plot_know_pre_pie(7)
plot_know_pre_pie(8)
plot_know_pre_pie(9)
plot_know_pre_pie(10)

# %%
def plot_box_Amp3_Time3(num):
    axes = dfgroupedlist[num-1][1].boxplot(column = 'Amp_3',by='Time_3',fontsize=10)
    plt.title('')
    fig = axes.get_figure()
    fig.suptitle(dict_category[num], fontsize=14, fontweight='bold')

# %%
plot_box_Amp3_Time3(1)
plot_box_Amp3_Time3(2)
plot_box_Amp3_Time3(3)
plot_box_Amp3_Time3(4)
plot_box_Amp3_Time3(5)
plot_box_Amp3_Time3(6)
plot_box_Amp3_Time3(7)
plot_box_Amp3_Time3(8)
plot_box_Amp3_Time3(9)
plot_box_Amp3_Time3(10)

# %%
dfgroupedlist[0][1]
# Out:
#       Category     Date  Time  All_Time  Time_1  Time_2  Time_3  All_Amp  \
# 2            1  1080121  1045         7       1       4       2      383
# 22           1  1080212  1045        11       2       7       2      342
# 40           1  1080222   945         8       2       5       1      232
# 82           1  1080331  1045         8       2       2       4      223
# 88           1  1080403   945        10       4       5       1      298
# 98           1  1080414   945        13       2       9       2      346
# 102          1  1080415  1145         6       2       3       1      129
# 110          1  1080422  1045        11       3       2       6      197
# 132          1  1080508   945        10       1       6       3      196
# 136          1  1080509  1045         5       2       1       2      112
# 174          1  1080609   945        12       3       4       5      326
# 182          1  1080617  1145        15       2       8       5      192
# 202          1  1080703   945        12       1       1      10      422
# 224          1  1080722  1045        10       3       5       2      421
# 268          1  1080821  1045         7       2       2       3      179
# 272          1  1080822  1145         5       1       2       2      209
# 278          1  1080828  1345        16       2       7       7      235
# 298          1  1080918  1045         8       1       1       6      583
# 300          1  1080922  1045        16       6       9       1      706
# 318          1  1081008  1345        12       3       4       5      420
# 322          1  1081015  1045        14       3      10       1      412
# 330          1  1081021  1245        11       4       4       3      314
# 334          1  1081028   945        21       1       1      19     1044
# 360          1  1081124  1145        11       4       3       4      314
# 372          1  1081202   945         6       1       3       2      312
# 390          1  1081215  1145         6       2       2       2      375
# 394          1  1081217  1245         9       1       6       2      213
# 398          1  1081219  1045         6       1       3       2      123
# 400          1  1081223  1145        13       2       4       7      465
# 404          1  1081225   945         6       1       4       1      158
# ...        ...      ...   ...       ...     ...     ...     ...      ...
# 3896         1  1170313  1345        10       1       7       2      143
# 3914         1  1170327  1345         7       3       1       3       73
# 3922         1  1170405  1245        13       9       3       1      127
# 3936         1  1170418  1145         9       3       4       2       92
# 3948         1  1170428  1245         9       2       4       3       76
# 3976         1  1170522  1245         6       2       2       2       47
# 3986         1  1170606   945        25       5      19       1      184
# 3990         1  1170608  1345        11       4       5       2       53
# 4002         1  1170621   945        20       1      16       3      335
# 4020         1  1170706  1045        11       6       4       1      158
# 4040         1  1170726  1345        16       2      10       4      136
# 4060         1  1170818   945         7       1       4       2      124
# 4062         1  1170822  1345        16       2      11       3      169
# 4068         1  1170828   945        12       1       8       3      149
# 4086         1  1170906  1145        11       4       4       3      102
# 4090         1  1170911  1145        12       4       6       2      158
# 4132         1  1171018  1145         5       2       1       2       97
# 4134         1  1171020   945        10       2       4       4      114
# 4142         1  1171026   945        11       1       5       5       89
# 4148         1  1171030  1045         5       3       1       1      136
# 4156         1  1171103  1245         9       1       5       3       55
# 4158         1  1171106  1045         6       3       2       1       83
# 4186         1  1171129  1145         6       2       2       2       68
# 4192         1  1171204   945         5       1       3       1      169
# 4254         1  1180202   945        14       4       6       4      182
# 4288         1  1180308  1345         8       3       3       2      141
# 4294         1  1180312  1345         7       1       5       1      198
# 4300         1  1180316  1145         8       1       2       5      145
# 4344         1  1180419  1245         7       2       4       1      186
# 4356         1  1180507  1045         7       2       4       1      147
#
#       Amp_1  Amp_2  Amp_3
# 2       271    383    157
# 22      229    342    215
# 40      179    232    129
# 82      122    163    223
# 88      275    298     91
# 98      192    346    122
# 102     108    129     64
# 110      89    175    197
# 132     100    196    141
# 136      85    103    112
# 174     147    326    306
# 182     150    192    174
# 202      78     95    422
# 224     289    421    134
# 268      90    179    179
# 272      73    120    209
# 278     152    235     86
# 298     116    320    583
# 300     583    706    166
# 318     262    263    420
# 322     369    412    144
# 330     248    314    215
# 334     149    160   1044
# 360     212    314    157
# 372      76    191    312
# 390     300    375    165
# 394     124    213    112
# 398      87    109    123
# 400     123    173    465
# 404     137    158     69
# ...     ...    ...    ...
# 3896    110    143     20
# 3914     71     73     52
# 3922     76    127     30
# 3936     80     92     51
# 3948     50     76     49
# 3976     28     47     13
# 3986     82    184     23
# 3990     37     53     13
# 4002     54    335     86
# 4020    135    158     92
# 4040     60    136    101
# 4060     84     89    124
# 4062    124    169     21
# 4068     40    149     33
# 4086     51     57    102
# 4090     91    158    100
# 4132     37     63     97
# 4134     97    114    100
# 4142     42     73     89
# 4148    108    136     96
# 4156     52     52     55
# 4158     55     73     83
# 4186     58     68     55
# 4192    114    169    100
# 4254    173    182    158
# 4288    111    141     24
# 4294     41    198     27
# 4300     65     83    145
# 4344    120    186     27
# 4356     72    147     86
#
# [315 rows x 11 columns]
